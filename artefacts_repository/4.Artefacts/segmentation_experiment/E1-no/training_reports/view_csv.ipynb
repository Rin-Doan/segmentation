# %%
import pandas as pd

# %%
convergence =  pd.read_csv('convergence.csv')
# inference = pd.read_csv('inference.csv')
training_efficiency = pd.read_csv('training_efficiency.csv')
# emissions = pd.read_csv('emissions.csv')

# %%
convergence
# Out:
#    Convergence Epoch  Total Training Time (hours)  \
# 0                  1                     0.545805
#
#    Total Training Time (second)  Average Epoch Time(s)  Average RAM (GB)  \
# 0                   1964.898736            1964.898736          1.319294
#
#    Average GPU Memory (GB)  Energy Consumed (kWh)  CO2 Emissions (kg)
# 0                 0.371512                    NaN                 NaN

# %%
training_efficiency
# Out:
#    Total Training Time (hours)  Total Training Time (second)  \
# 0                     0.545805                   1964.898736
#
#    Average Epoch Time(s)  Average RAM (GB)  Average GPU Memory (GB)  \
# 0            1964.898736          1.319294                 0.371512
#
#    Energy Consumed (kWh)  CO2 Emissions (kg)
# 0                    NaN             0.05105
